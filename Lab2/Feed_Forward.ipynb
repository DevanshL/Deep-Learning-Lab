# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
def sigmoid(x):
    return 1.0 / (1.0 + np.exp(-x))


def sigmoid_derivative(z):
    return z * (1.0 - z)

# %% [markdown]
# ### Node Class

# %%
class Neuron:
    def __init__(self, weights=None, delta=0.0, output=0.0):
        if weights is None:
            weights = []
        self.weights = weights
        self.delta = delta
        self.output = output

    def set_delta(self, error):
        self.delta = error * sigmoid_derivative(self.output)
    
    def weighted_sum(self, inputs):
        ws = 0.0
        for i in range(len(self.weights)):
            ws += self.weights[i] * inputs[i]
        return ws
    
    def activate(self, inputs):
        output = sigmoid(self.weighted_sum(inputs))
        self.output = output
        return output

# %% [markdown]
# ### Layer Class

# %%
class Layer:
    def __init__(self, neurons, bias_neuron=None):
        if bias_neuron is None:
            bias_neuron = Neuron()
        self.neurons = neurons
        self.bias_neuron = bias_neuron

    @property
    def all_outputs(self):
        total_neurons = [self.bias_neuron] + self.neurons  
        return [neuron.output for neuron in total_neurons]


    
    def activate_neurons(self, inputs):
        # Activate all neurons in the layer with given inputs
        return [neuron.activate(inputs) for neuron in self.neurons]
    
    def total_delta(self, previous_layer_neuron_idx):
        # total  for a given neuron index in the previous layer
        total = self.neurons
        return sum(
            neuron.weights[previous_layer_neuron_idx] * neuron.delta
            for neuron in total
        )

# %% [markdown]
# ### Network Class

# %%
class Network:
    def __init__(self, hidden_layers, output_layer, learning_rate):
        self.hidden_layers = hidden_layers
        self.output_layer = output_layer
        self.learning_rate = learning_rate

    def layers(self):
        return self.hidden_layers + [self.output_layer]

    def feed_forward(self, inputs):
        for layer in self.hidden_layers:
            inputs = [1.0,] + layer.activate_neurons(inputs)
        return self.output_layer.activate_neurons(inputs)

    def derivative_error_to_output(self, actual, expected):
        return [actual[i] - expected[i] for i in range(len(actual))]

    def back_propagate(self, inputs, errors):
        for index, neuron in enumerate(self.output_layer.neurons):
            neuron.set_delta(errors[index])

        for layer_idx in reversed(range(len(self.hidden_layers))):
            layer = self.hidden_layers[layer_idx]
            next_layer = (
                self.output_layer
                if layer_idx == len(self.hidden_layers) - 1
                else self.hidden_layers[layer_idx + 1]
            )
            for neuron_idx, neuron in enumerate(layer.neurons):
                error_from_next_layer = next_layer.total_delta(neuron_idx)
                neuron.set_delta(error_from_next_layer)

        self.update_weights_for_all_layers(inputs)

    def update_weights_for_all_layers(self, inputs):
        for layer_idx in range(len(self.hidden_layers)):
            layer = self.hidden_layers[layer_idx]
            previous_layer_outputs = (
                inputs
                if layer_idx == 0
                else self.hidden_layers[layer_idx - 1].all_outputs
            )
            for neuron in layer.neurons:
                self.update_weights_in_a_layer(previous_layer_outputs, neuron)

        for neuron in self.output_layer.neurons:
            self.update_weights_in_a_layer(self.hidden_layers[-1].all_outputs, neuron)

    def update_weights_in_a_layer(self, previous_layer_outputs, neuron):
        for idx in range(len(previous_layer_outputs)):
            neuron.weights[idx] -= (
                self.learning_rate * neuron.delta * previous_layer_outputs[idx]
            )

    def train(self, num_epoch, num_outputs, training_set, training_output):
        for epoch in range(num_epoch):
            sum_error = 0.0
            for idx, row in enumerate(training_set):
                expected = [0 for _ in range(num_outputs)]
                expected[training_output[idx]] = 1 
                actual = self.feed_forward(row)
                errors = self.derivative_error_to_output(actual, expected)
                
                self.back_propagate(row, errors)
                sum_error += self.mse(actual, expected)
            print(f"Mean squared error: {sum_error}")
            print(f"epoch={epoch}")

    def predict(self, inputs):
        outputs = self.feed_forward(inputs)
        return outputs.index(max(outputs))

    def mse(self, actual, expected):
        return sum((actual[i] - expected[i]) ** 2 for i in range(len(actual))) / len(actual)

# %%
import random

dataset = [[1.2, 0.9, 0.5]]
expected = [1]

n_outputs = 2

hidden_layers = [
    Layer(
        neurons=[
            Neuron(weights=[0.7, 1.2, 0.9]), 
            Neuron(weights=[0.6, 0.3, -1.2])
        ],
        bias_neuron=Neuron(output=1.0, weights=[0.8])
    )
]
output_layer = Layer(
    neurons=[
        Neuron(weights=[0.8, -1.3, 1.1]),
        Neuron(weights=[0.9, 1.5, -0.3])
    ]
)

network = Network(hidden_layers=hidden_layers, output_layer=output_layer, learning_rate=0.5)

network.train(500, n_outputs, dataset, expected)

prediction = network.predict([1.2, 0.9, 0.5])
print(f"The Predicted Class is {prediction}")
# Out:
# Mean squared error: 0.16641321562289807
# epoch=0
# Mean squared error: 0.14780246622949603
# epoch=1
# Mean squared error: 0.13080902526882196
# epoch=2
# Mean squared error: 0.11561202206734682
# epoch=3
# Mean squared error: 0.10224789296814739
# epoch=4
# Mean squared error: 0.09064145369882565
# epoch=5
# Mean squared error: 0.08064549349910959
# epoch=6
# Mean squared error: 0.07207719795829785
# epoch=7
# Mean squared error: 0.06474548083251087
# epoch=8
# Mean squared error: 0.05846829171900943
# epoch=9
# Mean squared error: 0.05308168395466943
# epoch=10
# Mean squared error: 0.04844320111250134
# epoch=11
# Mean squared error: 0.04443185742940751
# epoch=12
# Mean squared error: 0.040946358479664755
# epoch=13
# Mean squared error: 0.03790260556750692
# epoch=14
# Mean squared error: 0.035231076708805334
# epoch=15
# Mean squared error: 0.0328743829307698
# epoch=16
# Mean squared error: 0.03078512412989774
# epoch=17
# Mean squared error: 0.028924073682669818
# epoch=18
# Mean squared error: 0.027258674176896504
# epoch=19
# Mean squared error: 0.02576180709199406
# epoch=20
# Mean squared error: 0.02441079413431614
# epoch=21
# Mean squared error: 0.023186589790581042
# epoch=22
# Mean squared error: 0.02207312942284096
# epoch=23
# Mean squared error: 0.021056802784636286
# epoch=24
# Mean squared error: 0.020126028183369813
# epoch=25
# Mean squared error: 0.019270907232148967
# epoch=26
# Mean squared error: 0.018482944109651043
# epoch=27
# Mean squared error: 0.017754816505302015
# epoch=28
# Mean squared error: 0.017080188053888837
# epoch=29
# Mean squared error: 0.01645355415945292
# epoch=30
# Mean squared error: 0.01587011477012243
# epoch=31
# Mean squared error: 0.01532566897895836
# epoch=32
# Mean squared error: 0.014816527362590625
# epoch=33
# Mean squared error: 0.014339438787774139
# epoch=34
# Mean squared error: 0.013891529062690765
# epoch=35
# Mean squared error: 0.01347024932179591
# epoch=36
# Mean squared error: 0.013073332439270493
# epoch=37
# Mean squared error: 0.012698756089397476
# epoch=38
# Mean squared error: 0.012344711330159824
# epoch=39
# Mean squared error: 0.012009575792894606
# epoch=40
# Mean squared error: 0.011691890726736934
# epoch=41
# Mean squared error: 0.011390341280293408
# epoch=42
# Mean squared error: 0.011103739511115603
# epoch=43
# Mean squared error: 0.0108310097012892
# epoch=44
# Mean squared error: 0.0105711756289023
# epoch=45
# Mean squared error: 0.010323349503532309
# epoch=46
# Mean squared error: 0.010086722321743487
# epoch=47
# Mean squared error: 0.009860555437948252
# epoch=48
# Mean squared error: 0.009644173178462083
# epoch=49
# Mean squared error: 0.009436956353468048
# epoch=50
# Mean squared error: 0.009238336543931585
# epoch=51
# Mean squared error: 0.009047791059102627
# epoch=52
# Mean squared error: 0.008864838475777468
# epoch=53
# Mean squared error: 0.008689034683509452
# epoch=54
# Mean squared error: 0.00851996937089602
# epoch=55
# Mean squared error: 0.008357262897285958
# epoch=56
# Mean squared error: 0.00820056350203809
# epoch=57
# Mean squared error: 0.008049544810059636
# epoch=58
# Mean squared error: 0.007903903597956095
# epoch=59
# Mean squared error: 0.007763357789895629
# epoch=60
# Mean squared error: 0.0076276446563635514
# epoch=61
# Mean squared error: 0.007496519192467664
# epoch=62
# Mean squared error: 0.00736975265544389
# epoch=63
# Mean squared error: 0.007247131243580824
# epoch=64
# Mean squared error: 0.007128454900995271
# epoch=65
# Mean squared error: 0.0070135362346017156
# epoch=66
# Mean squared error: 0.006902199531272751
# epoch=67
# Mean squared error: 0.006794279864619999
# epoch=68
# Mean squared error: 0.006689622282071441
# epoch=69
# Mean squared error: 0.006588081064004632
# epoch=70
# Mean squared error: 0.006489519047640531
# epoch=71
# Mean squared error: 0.006393807009229166
# epoch=72
# Mean squared error: 0.006300823098780965
# epoch=73
# Mean squared error: 0.006210452322232102
# epoch=74
# Mean squared error: 0.006122586066488373
# epoch=75
# Mean squared error: 0.006037121663283223
# epoch=76
# Mean squared error: 0.005953961988216555
# epoch=77
# Mean squared error: 0.005873015091722734
# epoch=78
# Mean squared error: 0.005794193859053082
# epoch=79
# Mean squared error: 0.005717415696657054
# epoch=80
# Mean squared error: 0.005642602242610524
# epoch=81
# Mean squared error: 0.00556967909897528
# epoch=82
# Mean squared error: 0.005498575584182746
# epoch=83
# Mean squared error: 0.005429224503721339
# epoch=84
# Mean squared error: 0.005361561937573001
# epoch=85
# Mean squared error: 0.005295527042993054
# epoch=86
# Mean squared error: 0.005231061871359926
# epoch=87
# Mean squared error: 0.00516811119794071
# epoch=88
# Mean squared error: 0.005106622363524544
# epoch=89
# Mean squared error: 0.0050465451269718405
# epoch=90
# Mean squared error: 0.0049878315278134334
# epoch=91
# Mean squared error: 0.004930435758110813
# epoch=92
# Mean squared error: 0.004874314042858548
# epoch=93
# Mean squared error: 0.004819424528273145
# epoch=94
# Mean squared error: 0.004765727177368794
# epoch=95
# Mean squared error: 0.00471318367227222
# epoch=96
# Mean squared error: 0.0046617573227755085
# epoch=97
# Mean squared error: 0.0046114129806671105
# epoch=98
# Mean squared error: 0.004562116959420239
# epoch=99
# Mean squared error: 0.004513836958852135
# epoch=100
# Mean squared error: 0.0044665419943988385
# epoch=101
# Mean squared error: 0.004420202330679643
# epoch=102
# Mean squared error: 0.0043747894190502715
# epoch=103
# Mean squared error: 0.004330275838868853
# epoch=104
# Mean squared error: 0.004286635242219257
# epoch=105
# Mean squared error: 0.004243842301857021
# epoch=106
# Mean squared error: 0.004201872662160677
# epoch=107
# Mean squared error: 0.004160702892888022
# epoch=108
# Mean squared error: 0.004120310445551873
# epoch=109
# Mean squared error: 0.004080673612243908
# epoch=110
# Mean squared error: 0.004041771486747625
# epoch=111
# Mean squared error: 0.004003583927793366
# epoch=112
# Mean squared error: 0.003966091524318889
# epoch=113
# Mean squared error: 0.003929275562608931
# epoch=114
# Mean squared error: 0.003893117995196127
# epoch=115
# Mean squared error: 0.0038576014114140647
# epoch=116
# Mean squared error: 0.0038227090095009765
# epoch=117
# Mean squared error: 0.003788424570159486
# epoch=118
# Mean squared error: 0.0037547324314844495
# epoch=119
# Mean squared error: 0.003721617465177022
# epoch=120
# Mean squared error: 0.003689065053968452
# epoch=121
# Mean squared error: 0.003657061070182382
# epoch=122
# Mean squared error: 0.003625591855369318
# epoch=123
# Mean squared error: 0.0035946442009508694
# epoch=124
# Mean squared error: 0.0035642053298160824
# epoch=125
# Mean squared error: 0.0035342628788153476
# epoch=126
# Mean squared error: 0.0035048048821014243
# epoch=127
# Mean squared error: 0.003475819755269751
# epoch=128
# Mean squared error: 0.003447296280254041
# epoch=129
# Mean squared error: 0.003419223590934992
# epoch=130
# Mean squared error: 0.0033915911594235466
# epoch=131
# Mean squared error: 0.0033643887829816884
# epoch=132
# Mean squared error: 0.0033376065715466693
# epoch=133
# Mean squared error: 0.0033112349358262443
# epoch=134
# Mean squared error: 0.003285264575934757
# epoch=135
# Mean squared error: 0.00325968647054138
# epoch=136
# Mean squared error: 0.0032344918665039787
# epoch=137
# Mean squared error: 0.0032096722689632065
# epoch=138
# Mean squared error: 0.003185219431873284
# epoch=139
# Mean squared error: 0.0031611253489469524
# epoch=140
# Mean squared error: 0.003137382244993842
# epoch=141
# Mean squared error: 0.0031139825676321613
# epoch=142
# Mean squared error: 0.0030909189793552417
# epoch=143
# Mean squared error: 0.0030681843499351944
# epoch=144
# Mean squared error: 0.0030457717491471446
# epoch=145
# Mean squared error: 0.0030236744397982495
# epoch=146
# Mean squared error: 0.0030018858710467887
# epoch=147
# Mean squared error: 0.00298039967199726
# epoch=148
# Mean squared error: 0.0029592096455582093
# epoch=149
# Mean squared error: 0.0029383097625504733
# epoch=150
# Mean squared error: 0.0029176941560536676
# epoch=151
# Mean squared error: 0.0028973571159800807
# epoch=152
# Mean squared error: 0.002877293083865098
# epoch=153
# Mean squared error: 0.002857496647864311
# epoch=154
# Mean squared error: 0.0028379625379476386
# epoch=155
# Mean squared error: 0.002818685621281568
# epoch=156
# Mean squared error: 0.0027996608977909256
# epoch=157
# Mean squared error: 0.002780883495892031
# epoch=158
# Mean squared error: 0.002762348668389681
# epoch=159
# Mean squared error: 0.002744051788530458
# epoch=160
# Mean squared error: 0.002725988346205696
# epoch=161
# Mean squared error: 0.0027081539442972676
# epoch=162
# Mean squared error: 0.0026905442951601407
# epoch=163
# Mean squared error: 0.002673155217235651
# epoch=164
# Mean squared error: 0.0026559826317899453
# epoch=165
# Mean squared error: 0.0026390225597720824
# epoch=166
# Mean squared error: 0.0026222711187868517
# epoch=167
# Mean squared error: 0.002605724520177325
# epoch=168
# Mean squared error: 0.0025893790662126536
# epoch=169
# Mean squared error: 0.002573231147376451
# epoch=170
# Mean squared error: 0.002557277239751935
# epoch=171
# Mean squared error: 0.002541513902499543
# epoch=172
# Mean squared error: 0.0025259377754232493
# epoch=173
# Mean squared error: 0.0025105455766222017
# epoch=174
# Mean squared error: 0.0024953341002238367
# epoch=175
# Mean squared error: 0.002480300214195507
# epoch=176
# Mean squared error: 0.002465440858231281
# epoch=177
# Mean squared error: 0.0024507530417109792
# epoch=178
# Mean squared error: 0.0024362338417285583
# epoch=179
# Mean squared error: 0.002421880401187182
# epoch=180
# Mean squared error: 0.0024076899269581528
# epoch=181
# Mean squared error: 0.0023936596881015196
# epoch=182
# Mean squared error: 0.002379787014145697
# epoch=183
# Mean squared error: 0.002366069293423975
# epoch=184
# Mean squared error: 0.0023525039714656134
# epoch=185
# Mean squared error: 0.0023390885494396206
# epoch=186
# Mean squared error: 0.0023258205826490134
# epoch=187
# Mean squared error: 0.0023126976790737814
# epoch=188
# Mean squared error: 0.0022997174979606785
# epoch=189
# Mean squared error: 0.002286877748458101
# epoch=190
# Mean squared error: 0.002274176188294424
# epoch=191
# Mean squared error: 0.002261610622498058
# epoch=192
# Mean squared error: 0.0022491789021578815
# epoch=193
# Mean squared error: 0.0022368789232223834
# epoch=194
# Mean squared error: 0.002224708625336279
# epoch=195
# Mean squared error: 0.0022126659907130636
# epoch=196
# Mean squared error: 0.002200749043042414
# epoch=197
# Mean squared error: 0.002188955846431054
# epoch=198
# Mean squared error: 0.002177284504375826
# epoch=199
# Mean squared error: 0.002165733158768091
# epoch=200
# Mean squared error: 0.002154299988928027
# epoch=201
# Mean squared error: 0.002142983210668075
# epoch=202
# Mean squared error: 0.00213178107538424
# epoch=203
# Mean squared error: 0.0021206918691745328
# epoch=204
# Mean squared error: 0.002109713911983421
# epoch=205
# Mean squared error: 0.00209884555677153
# epoch=206
# Mean squared error: 0.002088085188709599
# epoch=207
# Mean squared error: 0.002077431224396001
# epoch=208
# Mean squared error: 0.002066882111096947
# epoch=209
# Mean squared error: 0.0020564363260086455
# epoch=210
# Mean squared error: 0.002046092375540605
# epoch=211
# Mean squared error: 0.0020358487946194803
# epoch=212
# Mean squared error: 0.0020257041460127875
# epoch=213
# Mean squared error: 0.0020156570196716134
# epoch=214
# Mean squared error: 0.002005706032092039
# epoch=215
# Mean squared error: 0.0019958498256943675
# epoch=216
# Mean squared error: 0.001986087068219693
# epoch=217
# Mean squared error: 0.0019764164521433097
# epoch=218
# Mean squared error: 0.0019668366941043183
# epoch=219
# Mean squared error: 0.001957346534350909
# epoch=220
# Mean squared error: 0.0019479447362008699
# epoch=221
# Mean squared error: 0.001938630085516867
# epoch=222
# Mean squared error: 0.001929401390195946
# epoch=223
# Mean squared error: 0.0019202574796727688
# epoch=224
# Mean squared error: 0.0019111972044363755
# epoch=225
# Mean squared error: 0.0019022194355597468
# epoch=226
# Mean squared error: 0.001893323064242036
# epoch=227
# Mean squared error: 0.0018845070013628487
# epoch=228
# Mean squared error: 0.0018757701770484277
# epoch=229
# Mean squared error: 0.0018671115402491855
# epoch=230
# Mean squared error: 0.0018585300583282875
# epoch=231
# Mean squared error: 0.001850024716661073
# epoch=232
# Mean squared error: 0.0018415945182447906
# epoch=233
# Mean squared error: 0.0018332384833184734
# epoch=234
# Mean squared error: 0.0018249556489926102
# epoch=235
# Mean squared error: 0.001816745068888282
# epoch=236
# Mean squared error: 0.0018086058127855685
# epoch=237
# Mean squared error: 0.0018005369662808428
# epoch=238
# Mean squared error: 0.0017925376304527873
# epoch=239
# Mean squared error: 0.0017846069215368288
# epoch=240
# Mean squared error: 0.0017767439706076983
# epoch=241
# Mean squared error: 0.0017689479232700055
# epoch=242
# Mean squared error: 0.0017612179393564618
# epoch=243
# Mean squared error: 0.0017535531926336175
# epoch=244
# Mean squared error: 0.0017459528705148718
# epoch=245
# Mean squared error: 0.0017384161737804959
# epoch=246
# Mean squared error: 0.0017309423163045796
# epoch=247
# Mean squared error: 0.001723530524788584
# epoch=248
# Mean squared error: 0.0017161800385014179
# epoch=249
# Mean squared error: 0.00170889010902577
# epoch=250
# Mean squared error: 0.0017016600000105504
# epoch=251
# Mean squared error: 0.0016944889869293077
# epoch=252
# Mean squared error: 0.0016873763568444047
# epoch=253
# Mean squared error: 0.0016803214081768025
# epoch=254
# Mean squared error: 0.0016733234504813215
# epoch=255
# Mean squared error: 0.0016663818042271957
# epoch=256
# Mean squared error: 0.0016594958005838225
# epoch=257
# Mean squared error: 0.00165266478121149
# epoch=258
# Mean squared error: 0.0016458880980570346
# epoch=259
# Mean squared error: 0.0016391651131542131
# epoch=260
# Mean squared error: 0.001632495198428778
# epoch=261
# Mean squared error: 0.0016258777355078976
# epoch=262
# Mean squared error: 0.0016193121155341638
# epoch=263
# Mean squared error: 0.0016127977389836724
# epoch=264
# Mean squared error: 0.0016063340154883717
# epoch=265
# Mean squared error: 0.0015999203636624273
# epoch=266
# Mean squared error: 0.0015935562109324803
# epoch=267
# Mean squared error: 0.0015872409933717657
# epoch=268
# Mean squared error: 0.0015809741555379646
# epoch=269
# Mean squared error: 0.0015747551503146801
# epoch=270
# Mean squared error: 0.0015685834387564263
# epoch=271
# Mean squared error: 0.001562458489937136
# epoch=272
# Mean squared error: 0.001556379780801911
# epoch=273
# Mean squared error: 0.0015503467960221425
# epoch=274
# Mean squared error: 0.0015443590278537847
# epoch=275
# Mean squared error: 0.001538415975998711
# epoch=276
# Mean squared error: 0.0015325171474691065
# epoch=277
# Mean squared error: 0.0015266620564548519
# epoch=278
# Mean squared error: 0.0015208502241937172
# epoch=279
# Mean squared error: 0.0015150811788443772
# epoch=280
# Mean squared error: 0.001509354455362205
# epoch=281
# Mean squared error: 0.0015036695953776751
# epoch=282
# Mean squared error: 0.0014980261470773507
# epoch=283
# Mean squared error: 0.0014924236650874815
# epoch=284
# Mean squared error: 0.0014868617103600008
# epoch=285
# Mean squared error: 0.0014813398500609417
# epoch=286
# Mean squared error: 0.001475857657461241
# epoch=287
# Mean squared error: 0.0014704147118297978
# epoch=288
# Mean squared error: 0.0014650105983287647
# epoch=289
# Mean squared error: 0.0014596449079110768
# epoch=290
# Mean squared error: 0.0014543172372200308
# epoch=291
# Mean squared error: 0.0014490271884909944
# epoch=292
# Mean squared error: 0.0014437743694551588
# epoch=293
# Mean squared error: 0.0014385583932451877
# epoch=294
# Mean squared error: 0.001433378878302906
# epoch=295
# Mean squared error: 0.001428235448288785
# epoch=296
# Mean squared error: 0.0014231277319933225
# epoch=297
# Mean squared error: 0.0014180553632502117
# epoch=298
# Mean squared error: 0.0014130179808512224
# epoch=299
# Mean squared error: 0.0014080152284628802
# epoch=300
# Mean squared error: 0.0014030467545447173
# epoch=301
# Mean squared error: 0.001398112212269268
# epoch=302
# Mean squared error: 0.0013932112594435562
# epoch=303
# Mean squared error: 0.0013883435584322178
# epoch=304
# Mean squared error: 0.0013835087760821012
# epoch=305
# Mean squared error: 0.0013787065836483995
# epoch=306
# Mean squared error: 0.0013739366567222006
# epoch=307
# Mean squared error: 0.0013691986751594655
# epoch=308
# Mean squared error: 0.0013644923230114068
# epoch=309
# Mean squared error: 0.0013598172884562217
# epoch=310
# Mean squared error: 0.0013551732637321586
# epoch=311
# Mean squared error: 0.0013505599450718475
# epoch=312
# Mean squared error: 0.0013459770326379272
# epoch=313
# Mean squared error: 0.0013414242304599184
# epoch=314
# Mean squared error: 0.0013369012463723003
# epoch=315
# Mean squared error: 0.001332407791953725
# epoch=316
# Mean squared error: 0.0013279435824674777
# epoch=317
# Mean squared error: 0.0013235083368030118
# epoch=318
# Mean squared error: 0.0013191017774185874
# epoch=319
# Mean squared error: 0.0013147236302850011
# epoch=320
# Mean squared error: 0.0013103736248304219
# epoch=321
# Mean squared error: 0.0013060514938861719
# epoch=322
# Mean squared error: 0.0013017569736336102
# epoch=323
# Mean squared error: 0.0012974898035519608
# epoch=324
# Mean squared error: 0.001293249726367083
# epoch=325
# Mean squared error: 0.0012890364880013033
# epoch=326
# Mean squared error: 0.0012848498375239933
# epoch=327
# Mean squared error: 0.0012806895271032645
# epoch=328
# Mean squared error: 0.0012765553119583931
# epoch=329
# Mean squared error: 0.001272446950313177
# epoch=330
# Mean squared error: 0.0012683642033501589
# epoch=331
# Mean squared error: 0.001264306835165624
# epoch=332
# Mean squared error: 0.0012602746127255069
# epoch=333
# Mean squared error: 0.0012562673058220016
# epoch=334
# Mean squared error: 0.0012522846870309883
# epoch=335
# Mean squared error: 0.0012483265316702813
# epoch=336
# Mean squared error: 0.0012443926177585257
# epoch=337
# Mean squared error: 0.0012404827259749121
# epoch=338
# Mean squared error: 0.0012365966396195522
# epoch=339
# Mean squared error: 0.0012327341445746106
# epoch=340
# Mean squared error: 0.001228895029266076
# epoch=341
# Mean squared error: 0.0012250790846262296
# epoch=342
# Mean squared error: 0.0012212861040567999
# epoch=343
# Mean squared error: 0.0012175158833927194
# epoch=344
# Mean squared error: 0.001213768220866541
# epoch=345
# Mean squared error: 0.001210042917073478
# epoch=346
# Mean squared error: 0.0012063397749370241
# epoch=347
# Mean squared error: 0.0012026585996752321
# epoch=348
# Mean squared error: 0.0011989991987675043
# epoch=349
# Mean squared error: 0.0011953613819219917
# epoch=350
# Mean squared error: 0.0011917449610435748
# epoch=351
# Mean squared error: 0.0011881497502023598
# epoch=352
# Mean squared error: 0.001184575565602689
# epoch=353
# Mean squared error: 0.0011810222255527955
# epoch=354
# Mean squared error: 0.0011774895504348306
# epoch=355
# Mean squared error: 0.001173977362675474
# epoch=356
# Mean squared error: 0.0011704854867170631
# epoch=357
# Mean squared error: 0.0011670137489891408
# epoch=358
# Mean squared error: 0.0011635619778805465
# epoch=359
# Mean squared error: 0.0011601300037119594
# epoch=360
# Mean squared error: 0.001156717658708848
# epoch=361
# Mean squared error: 0.0011533247769749454
# epoch=362
# Mean squared error: 0.0011499511944661513
# epoch=363
# Mean squared error: 0.0011465967489648066
# epoch=364
# Mean squared error: 0.0011432612800544883
# epoch=365
# Mean squared error: 0.0011399446290951197
# epoch=366
# Mean squared error: 0.0011366466391985821
# epoch=367
# Mean squared error: 0.0011333671552046782
# epoch=368
# Mean squared error: 0.0011301060236574775
# epoch=369
# Mean squared error: 0.0011268630927820972
# epoch=370
# Mean squared error: 0.0011236382124618163
# epoch=371
# Mean squared error: 0.001120431234215572
# epoch=372
# Mean squared error: 0.001117242011175838
# epoch=373
# Mean squared error: 0.001114070398066835
# epoch=374
# Mean squared error: 0.0011109162511831396
# epoch=375
# Mean squared error: 0.0011077794283685478
# epoch=376
# Mean squared error: 0.0011046597889953912
# epoch=377
# Mean squared error: 0.0011015571939440643
# epoch=378
# Mean squared error: 0.0010984715055830097
# epoch=379
# Mean squared error: 0.0010954025877488878
# epoch=380
# Mean squared error: 0.0010923503057271627
# epoch=381
# Mean squared error: 0.001089314526232944
# epoch=382
# Mean squared error: 0.001086295117392136
# epoch=383
# Mean squared error: 0.0010832919487229202
# epoch=384
# Mean squared error: 0.0010803048911174665
# epoch=385
# Mean squared error: 0.0010773338168239667
# epoch=386
# Mean squared error: 0.0010743785994289917
# epoch=387
# Mean squared error: 0.0010714391138400073
# epoch=388
# Mean squared error: 0.001068515236268297
# epoch=389
# Mean squared error: 0.001065606844212036
# epoch=390
# Mean squared error: 0.0010627138164397078
# epoch=391
# Mean squared error: 0.001059836032973723
# epoch=392
# Mean squared error: 0.0010569733750743241
# epoch=393
# Mean squared error: 0.001054125725223721
# epoch=394
# Mean squared error: 0.0010512929671104676
# epoch=395
# Mean squared error: 0.0010484749856141005
# epoch=396
# Mean squared error: 0.0010456716667899542
# epoch=397
# Mean squared error: 0.0010428828978542868
# epoch=398
# Mean squared error: 0.0010401085671695692
# epoch=399
# Mean squared error: 0.0010373485642300138
# epoch=400
# Mean squared error: 0.0010346027796473345
# epoch=401
# Mean squared error: 0.0010318711051367122
# epoch=402
# Mean squared error: 0.0010291534335029682
# epoch=403
# Mean squared error: 0.0010264496586269265
# epoch=404
# Mean squared error: 0.0010237596754520267
# epoch=405
# Mean squared error: 0.0010210833799710998
# epoch=406
# Mean squared error: 0.001018420669213335
# epoch=407
# Mean squared error: 0.0010157714412314795
# epoch=408
# Mean squared error: 0.0010131355950891686
# epoch=409
# Mean squared error: 0.001010513030848514
# epoch=410
# Mean squared error: 0.0010079036495577957
# epoch=411
# Mean squared error: 0.0010053073532394164
# epoch=412
# Mean squared error: 0.0010027240448779561
# epoch=413
# Mean squared error: 0.0010001536284084498
# epoch=414
# Mean squared error: 0.0009975960087048343
# epoch=415
# Mean squared error: 0.0009950510915685213
# epoch=416
# Mean squared error: 0.0009925187837171998
# epoch=417
# Mean squared error: 0.0009899989927737336
# epoch=418
# Mean squared error: 0.000987491627255276
# epoch=419
# Mean squared error: 0.0009849965965625048
# epoch=420
# Mean squared error: 0.000982513810969032
# epoch=421
# Mean squared error: 0.0009800431816109382
# epoch=422
# Mean squared error: 0.0009775846204764977
# epoch=423
# Mean squared error: 0.0009751380403960178
# epoch=424
# Mean squared error: 0.0009727033550318302
# epoch=425
# Mean squared error: 0.0009702804788684361
# epoch=426
# Mean squared error: 0.0009678693272027617
# epoch=427
# Mean squared error: 0.0009654698161346052
# epoch=428
# Mean squared error: 0.0009630818625571329
# epoch=429
# Mean squared error: 0.0009607053841476291
# epoch=430
# Mean squared error: 0.0009583402993582387
# epoch=431
# Mean squared error: 0.000955986527406948
# epoch=432
# Mean squared error: 0.0009536439882686396
# epoch=433
# Mean squared error: 0.0009513126026663029
# epoch=434
# Mean squared error: 0.0009489922920622978
# epoch=435
# Mean squared error: 0.0009466829786498338
# epoch=436
# Mean squared error: 0.0009443845853445317
# epoch=437
# Mean squared error: 0.0009420970357760272
# epoch=438
# Mean squared error: 0.0009398202542798388
# epoch=439
# Mean squared error: 0.0009375541658891873
# epoch=440
# Mean squared error: 0.000935298696327062
# epoch=441
# Mean squared error: 0.000933053771998314
# epoch=442
# Mean squared error: 0.0009308193199818794
# epoch=443
# Mean squared error: 0.0009285952680230963
# epoch=444
# Mean squared error: 0.0009263815445261806
# epoch=445
# Mean squared error: 0.0009241780785467187
# epoch=446
# Mean squared error: 0.0009219847997843443
# epoch=447
# Mean squared error: 0.0009198016385754341
# epoch=448
# Mean squared error: 0.0009176285258859927
# epoch=449
# Mean squared error: 0.0009154653933045316
# epoch=450
# Mean squared error: 0.0009133121730351434
# epoch=451
# Mean squared error: 0.0009111687978905836
# epoch=452
# Mean squared error: 0.0009090352012855081
# epoch=453
# Mean squared error: 0.0009069113172297718
# epoch=454
# Mean squared error: 0.0009047970803217998
# epoch=455
# Mean squared error: 0.0009026924257420864
# epoch=456
# Mean squared error: 0.0009005972892467528
# epoch=457
# Mean squared error: 0.0008985116071612069
# epoch=458
# Mean squared error: 0.0008964353163738439
# epoch=459
# Mean squared error: 0.0008943683543299185
# epoch=460
# Mean squared error: 0.0008923106590253869
# epoch=461
# Mean squared error: 0.0008902621690009148
# epoch=462
# Mean squared error: 0.0008882228233359156
# epoch=463
# Mean squared error: 0.0008861925616427109
# epoch=464
# Mean squared error: 0.0008841713240607069
# epoch=465
# Mean squared error: 0.0008821590512507005
# epoch=466
# Mean squared error: 0.0008801556843892262
# epoch=467
# Mean squared error: 0.0008781611651629989
# epoch=468
# Mean squared error: 0.0008761754357634031
# epoch=469
# Mean squared error: 0.0008741984388810908
# epoch=470
# Mean squared error: 0.0008722301177005866
# epoch=471
# Mean squared error: 0.0008702704158950382
# epoch=472
# Mean squared error: 0.0008683192776209755
# epoch=473
# Mean squared error: 0.0008663766475131662
# epoch=474
# Mean squared error: 0.0008644424706795206
# epoch=475
# Mean squared error: 0.0008625166926960733
# epoch=476
# Mean squared error: 0.000860599259602019
# epoch=477
# Mean squared error: 0.000858690117894828
# epoch=478
# Mean squared error: 0.0008567892145253902
# epoch=479
# Mean squared error: 0.0008548964968932617
# epoch=480
# Mean squared error: 0.0008530119128419391
# epoch=481
# Mean squared error: 0.0008511354106542136
# epoch=482
# Mean squared error: 0.0008492669390475589
# epoch=483
# Mean squared error: 0.0008474064471696136
# epoch=484
# Mean squared error: 0.0008455538845936742
# epoch=485
# Mean squared error: 0.0008437092013142888
# epoch=486
# Mean squared error: 0.000841872347742887
# epoch=487
# Mean squared error: 0.000840043274703435
# epoch=488
# Mean squared error: 0.0008382219334281999
# epoch=489
# Mean squared error: 0.0008364082755535297
# epoch=490
# Mean squared error: 0.0008346022531156975
# epoch=491
# Mean squared error: 0.0008328038185467634
# epoch=492
# Mean squared error: 0.0008310129246705622
# epoch=493
# Mean squared error: 0.0008292295246986794
# epoch=494
# Mean squared error: 0.0008274535722264736
# epoch=495
# Mean squared error: 0.0008256850212291754
# epoch=496
# Mean squared error: 0.0008239238260580297
# epoch=497
# Mean squared error: 0.000822169941436487
# epoch=498
# Mean squared error: 0.0008204233224564052
# epoch=499
# The Predicted Class is 1
